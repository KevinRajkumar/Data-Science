# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics                          
from sklearn.neighbors import KNeighborsClassifier    
from scipy.stats import zscore                       
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn import model_selection
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
colnames=['cul','alco','malic','ash','alca','mag','pheno','flavo','nonflavo','proanth','color','hue','od280/od315','pro']

# %%
df=pd.read_csv('wine.xls',names=colnames)

# %%
df.head()
# Out:
#    cul   alco  malic   ash  alca  mag  pheno  flavo  nonflavo  proanth  color  \
# 0    1  14.23   1.71  2.43  15.6  127   2.80   3.06      0.28     2.29   5.64
# 1    1  13.20   1.78  2.14  11.2  100   2.65   2.76      0.26     1.28   4.38
# 2    1  13.16   2.36  2.67  18.6  101   2.80   3.24      0.30     2.81   5.68
# 3    1  14.37   1.95  2.50  16.8  113   3.85   3.49      0.24     2.18   7.80
# 4    1  13.24   2.59  2.87  21.0  118   2.80   2.69      0.39     1.82   4.32
#
#     hue  od280/od315   pro
# 0  1.04         3.92  1065
# 1  1.05         3.40  1050
# 2  1.03         3.17  1185
# 3  0.86         3.45  1480
# 4  1.04         2.93   735

# %%
df.describe().transpose()
# Out:
#              count        mean         std     min       25%      50%  \
# cul          178.0    1.938202    0.775035    1.00    1.0000    2.000
# alco         178.0   13.000618    0.811827   11.03   12.3625   13.050
# malic        178.0    2.336348    1.117146    0.74    1.6025    1.865
# ash          178.0    2.366517    0.274344    1.36    2.2100    2.360
# alca         178.0   19.494944    3.339564   10.60   17.2000   19.500
# mag          178.0   99.741573   14.282484   70.00   88.0000   98.000
# pheno        178.0    2.295112    0.625851    0.98    1.7425    2.355
# flavo        178.0    2.029270    0.998859    0.34    1.2050    2.135
# nonflavo     178.0    0.361854    0.124453    0.13    0.2700    0.340
# proanth      178.0    1.590899    0.572359    0.41    1.2500    1.555
# color        178.0    5.058090    2.318286    1.28    3.2200    4.690
# hue          178.0    0.957449    0.228572    0.48    0.7825    0.965
# ...

# %%
df.dtypes
# Out:
# cul              int64
# alco           float64
# malic          float64
# ash            float64
# alca           float64
# mag              int64
# pheno          float64
# flavo          float64
# nonflavo       float64
# proanth        float64
# color          float64
# hue            float64
# od280/od315    float64
# pro              int64
# dtype: object

# %%
x1=df.drop('cul',axis=1)
y=df['cul']

# %%
x=StandardScaler().fit_transform(x1)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=2)

# %%
modelr=RandomForestClassifier(n_estimators=40,criterion='entropy',random_state=0,max_depth=2)
modelr.fit(x_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#             max_depth=2, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=40, n_jobs=None,
#             oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
from sklearn.model_selection import GridSearchCV

params={'max_depth':np.arange(1,11),'n_estimators':np.arange(1,60)}
gs=GridSearchCV(model1,params,cv=3)
gs.fit(x,y)
print(gs.best_params_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-97e442749e0f> in <module>
#       2
#       3 params={'max_depth':np.arange(1,11),'n_estimators':np.arange(1,60)}
# ----> 4 gs=GridSearchCV(model1,params,cv=3)
#       5 gs.fit(x,y)
#       6 print(gs.best_params_)
#
# NameError: name 'model1' is not defined

# %%
modeld=DecisionTreeClassifier(criterion='entropy',random_state=0,max_depth=4)
modeld.fit(x_train,y_train)

# %%
from sklearn.model_selection import GridSearchCV

params={'max_depth':np.arange(1,11)}
gs=GridSearchCV(model2,params,cv=3)
gs.fit(x,y)
print(gs.best_params_)

# %%
model3 = GaussianNB()
model3.fit(x_train,y_train)

# %%
model4=LogisticRegression()
model4.fit(x_train,y_train)

# %%
y_pred1=model1.predict(x_test)
y_pred2=model2.predict(x_test)
y_pred3=model3.predict(x_test)
y_pred4=model4.predict(x_test)

# %%
acc1=metrics.accuracy_score(y_test,y_pred1)
print(acc1)
acc2=metrics.accuracy_score(y_test,y_pred2)
print(acc2)
acc3=metrics.accuracy_score(y_test,y_pred3)
print(acc3)
acc4=metrics.accuracy_score(y_test,y_pred4)
print(acc4)

# %%
cm1=metrics.confusion_matrix(y_test,y_pred1)
print(cm1)
cm2=metrics.confusion_matrix(y_test,y_pred2)
print(cm2)
cm3=metrics.confusion_matrix(y_test,y_pred3)
print(cm3)
cm4=metrics.confusion_matrix(y_test,y_pred4)
print(cm4)

# %%
cr1=metrics.classification_report(y_test,y_pred1)
print(cr1)
cr2=metrics.classification_report(y_test,y_pred2)
print(cr2)
cr3=metrics.classification_report(y_test,y_pred3)
print(cr3)
cr4=metrics.classification_report(y_test,y_pred4)
print(cr4)

# %%
models=[]

models.append(('DecisionTree',modeld))
models.append(('RandomForest',modelr))
models.append(('Naive Bayes ',model3))
models.append(('Logistic    ',model4))

results=[]
names=[]

scoring='accuracy'

for name,model in models:
    kfold=model_selection.KFold(n_splits=10,random_state=2)
    cv_results=model_selection.cross_val_score(model,x,y,cv=kfold,scoring=scoring)
    results.append(cv_results)
    names.append(name)
    msg="%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
    print(msg)
    
# boxplot algorithm comparison
fig=plt.figure()
fig.suptitle('Algorithm Comparison')
ax=fig.add_subplot(111)
plt.boxplot(results)
ax.set_xticklabels(names)
plt.show()
